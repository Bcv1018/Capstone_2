# %% [markdown]
# # Placeholder for capstone description and what sales territries are mine

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
# loading in customer_list csv
pd.read_csv('customer_list.csv')

# %%
# Loading in productcategories.csv
pd.read_csv('ProductCategories.csv')

# %%
# Loading in Products.csv
pd.read_csv('Products.csv')

# %%
# Loading in StoreDetail.csv
pd.read_csv('StoreDetail.csv')

# %%
# Loading in StoreSales.csv
pd.read_csv('StoreSales.csv')
