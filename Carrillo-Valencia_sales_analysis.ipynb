# %% [markdown]
# # Capstone 2: Business Analysis with Python
# ## EmporiUm Student Bookstore Market Analysis
# * Region: South
#     - Territory 1: South Carolina
#         * Manager: Len Jensen
#     - Territory 2: Texas
#         * Manager: Jeff "Howdy" Richards
#
# I have been assigned to comparatively analyze two different territories sales by finding inforamtion about the territories, monthly total revenue for each stores in the territories, create a ranking system of the stores and finding the top perfoming stores for each territory,
# finding the top rewards members in each territory, counting the number of transactions by product category and monthly total sales revenue by category.

# %% [markdown]
# ## Importing csv files that are needed

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# loading in customer_list.csv
cx_list = pd.read_csv('customer_list.csv', sep='|')
cx_list.head(10)
# Out:
#    cust_id        date      time           name  \
# 0        1  2023-03-15  08:45:12         Rachel
# 1        2  2023-05-22  12:30:45      R. Geller
# 2        3  2023-07-09  18:15:27  Monica Geller
# 3        4  2023-09-01  21:05:33  Chandler Bing
# 4        5  2023-11-18  14:22:10           Joey
# 5        6  2024-01-05  10:55:49      P. Buffay
# 6        7  2024-02-14  16:40:05        Gunther
# 7        8  2023-04-20  09:15:30         Janice
# 8        9  2023-06-30  13:50:55        Mike H.
# 9       10  2023-08-25  17:25:10          Emily
#
#                             email         phone sms-opt-out
# 0       rachel@centralperk.coffee  212-555-1001            N
# 1        rossg@centralperk.coffee  212-555-1002            N
# 2   chefmonica@centralperk.coffee  212-555-1003            N
# 3    chandlerb@centralperk.coffee  212-555-1004            Y
# 4  howyoudoing@centralperk.coffee  212-555-1005            N
# 5    smellycat@centralperk.coffee  212-555-1006            N
# ...

# %%
cx_list.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cust_id       521 non-null    int64
#  1   date          521 non-null    str
#  2   time          521 non-null    str
#  3   name          521 non-null    str
#  4   email         521 non-null    str
#  5   phone         520 non-null    str
#  6   sms-opt-out   520 non-null    str
# dtypes: int64(1), str(6)
# memory usage: 28.6 KB

# %%
# Loading in productcategories.csv
prod_cats = pd.read_csv('ProductCategories.csv')
prod_cats.head(10)
# Out:
#    CategoryID                  Category SubcategoryID  \
# 0         120  Technology & Accessories       120-tab
# 1         120  Technology & Accessories       120-cal
# 2         120  Technology & Accessories       120-sof
# 3         120  Technology & Accessories       120-hea
# 4         120  Technology & Accessories       120-ext
# 5         120  Technology & Accessories       120-cha
# 6         120  Technology & Accessories       120-lap
# 7         130   Apparel and Merchandise       130-off
# 8         100                 Textbooks       100-bus
# 9         130   Apparel and Merchandise       130-clo
#
#                                  Subcategory
# 0                                    Tablets
# 1                                Calculators
# 2                          Software Download
# 3                                 Headphones
# 4                       External Accessories
# 5                Chargers and Power Adapters
# 6                                    Laptops
# ...

# %%
prod_cats.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CategoryID     52 non-null     int64
#  1   Category       52 non-null     str
#  2   SubcategoryID  52 non-null     str
#  3   Subcategory    52 non-null     str
# dtypes: int64(1), str(3)
# memory usage: 1.8 KB

# %%
# Loading in Products.csv
products = pd.read_csv('Products.csv')
products.head(10)
# Out:
#     Prod Num                         Product  CategoryID SubcategoryID
# 0  105248-IT                TCL NXTPAPER 10s         120       120-tab
# 1  105249-IT   Dell Latitude 7320 Detachable         120       120-tab
# 2  105250-IT                      Realme Pad         120       120-tab
# 3  105251-IT              Lenovo Tab P12 Pro         120       120-tab
# 4  105252-IT         Microsoft Surface Pro 9         120       120-tab
# 5  105253-IT  Apple iPad Pro (12.9-inch, M2)         120       120-tab
# 6  105254-IT                 Chuwi HiPad Max         120       120-tab
# 7  105255-IT           Lenovo Yoga Smart Tab         120       120-tab
# 8  105256-IT     ASUS Vivobook 13 Slate OLED         120       120-tab
# 9  105257-IT     Samsung Galaxy Tab S9 Ultra         120       120-tab

# %%
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Prod Num       669 non-null    str
#  1   Product        669 non-null    str
#  2   CategoryID     669 non-null    int64
#  3   SubcategoryID  669 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 21.0 KB

# %%
# Loading in StoreDetail.csv
store_detail = pd.read_csv('StoreDetail.csv')
store_detail.tail(13)
# Out:
#     Store Location           State  Store ID      Territory Manager Region  \
# 98      Charleston  South Carolina       852             Len Jensen  South
# 99      Greenville  South Carolina       853             Len Jensen  South
# 100      Arlington           Texas       901  Jeff "Howdy" Richards  South
# 101         Austin           Texas       902  Jeff "Howdy" Richards  South
# 102        Bacliff           Texas       903  Jeff "Howdy" Richards  South
# 103        Baytown           Texas       904  Jeff "Howdy" Richards  South
# 104       Beaumont           Texas       905  Jeff "Howdy" Richards  South
# 105     Cedar Park           Texas       906  Jeff "Howdy" Richards  South
# 106         Dallas           Texas       907  Jeff "Howdy" Richards  South
# 107         Denton           Texas       908  Jeff "Howdy" Richards  South
# 108         Desoto           Texas       909  Jeff "Howdy" Richards  South
# ...

# %%
store_detail.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Store Location     111 non-null    str
#  1   State              111 non-null    str
#  2   Store ID           111 non-null    int64
#  3   Territory Manager  111 non-null    str
#  4   Region             111 non-null    str
#  5   Region Director    111 non-null    str
# dtypes: int64(1), str(5)
# memory usage: 5.3 KB

# %%
# Loading in StoreSales.csv
store_sales = pd.read_csv('StoreSales.csv')
store_sales.head(10)
# Out:
#   Transaction Date  Store ID  RewardsID   Prod Num  Sale Amount
# 0         1/1/2022       702        NaN   105349-M         8.00
# 1         1/1/2022       704        NaN   105350-T       144.00
# 2         1/1/2022       705        NaN   105351-M        44.00
# 3         1/1/2022       705        NaN   105352-M        47.61
# 4         1/1/2022       705        NaN   105353-A        20.36
# 5         1/1/2022       706        NaN  105344-IT       265.07
# 6         1/1/2022       707        NaN   105354-T       133.10
# 7         1/1/2022       707        NaN   105355-B        24.28
# 8         1/1/2022       708        NaN   105356-S        13.13
# 9         1/1/2022       709        NaN   105357-T       195.30

# %%
store_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 335129 entries, 0 to 335128
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction Date  335129 non-null  str
#  1   Store ID          335129 non-null  int64
#  2   RewardsID         34943 non-null   float64
#  3   Prod Num          335129 non-null  str
#  4   Sale Amount       335129 non-null  float64
# dtypes: float64(2), int64(1), str(2)
# memory usage: 12.8 MB

# %% [markdown]
# ## Core Marketing Analysis

# %% [markdown]
# ### Who are the territory managers for the sales territories assigned? What are the store IDs and cities for the stores in each assigned sales territory?

# %%
state_info = store_detail[(store_detail['State'] == 'Texas') | (store_detail['State'] == 'South Carolina')] # Filters store_detail df to only show rows that have either Texas or South Carolina
territory_info = state_info[['Store ID','Store Location','State','Territory Manager']] # creates a new df that will only show the columns that are relevant right now
territory_info.set_index('Store ID', inplace=True) # sets Store ID to be the index of the territory_info df

# Calls territory_info DF 
territory_info
# Territory Manager for Texas is Jeff "Howdy" Richards 
# Teriitroy Manager for South Carolina is Len Jensen
# Store IDs for South Carolina are 852 and 853
# Store Ids for Texas are 901-911
# Out:
#          Store Location           State      Territory Manager
# Store ID
# 852          Charleston  South Carolina             Len Jensen
# 853          Greenville  South Carolina             Len Jensen
# 901           Arlington           Texas  Jeff "Howdy" Richards
# 902              Austin           Texas  Jeff "Howdy" Richards
# 903             Bacliff           Texas  Jeff "Howdy" Richards
# 904             Baytown           Texas  Jeff "Howdy" Richards
# 905            Beaumont           Texas  Jeff "Howdy" Richards
# 906          Cedar Park           Texas  Jeff "Howdy" Richards
# 907              Dallas           Texas  Jeff "Howdy" Richards
# 908              Denton           Texas  Jeff "Howdy" Richards
# 909              Desoto           Texas  Jeff "Howdy" Richards
# 910          Fort Worth           Texas  Jeff "Howdy" Richards
# 911          Georgetown           Texas  Jeff "Howdy" Richards

# %% [markdown]
# ### What is monthly total revenue for in-store sales in each of the two sales territories, over the full period covered by the data?

# %%
# Merging store sales with territory_info to create a new df 
territory_sales = pd.merge(territory_info, store_sales, on=['Store ID'])

territory_sales
# Out:
#        Store ID Store Location           State      Territory Manager  \
# 0           852     Charleston  South Carolina             Len Jensen
# 1           852     Charleston  South Carolina             Len Jensen
# 2           852     Charleston  South Carolina             Len Jensen
# 3           852     Charleston  South Carolina             Len Jensen
# 4           852     Charleston  South Carolina             Len Jensen
# ...         ...            ...             ...                    ...
# 28679       911     Georgetown           Texas  Jeff "Howdy" Richards
# 28680       911     Georgetown           Texas  Jeff "Howdy" Richards
# 28681       911     Georgetown           Texas  Jeff "Howdy" Richards
# 28682       911     Georgetown           Texas  Jeff "Howdy" Richards
# 28683       911     Georgetown           Texas  Jeff "Howdy" Richards
#
#       Transaction Date  RewardsID   Prod Num  Sale Amount
# 0             1/3/2022        NaN   105615-B        28.92
# ...

# %%
# Converting transaction date from str to an actual date value and adding new date column that is only monthly
territory_sales['Transaction Date'] = pd.to_datetime(territory_sales['Transaction Date'])
territory_sales['Date'] = territory_sales['Transaction Date'].dt.to_period('M')

territory_sales
# Out:
#        Store ID Store Location           State      Territory Manager  \
# 0           852     Charleston  South Carolina             Len Jensen
# 1           852     Charleston  South Carolina             Len Jensen
# 2           852     Charleston  South Carolina             Len Jensen
# 3           852     Charleston  South Carolina             Len Jensen
# 4           852     Charleston  South Carolina             Len Jensen
# ...         ...            ...             ...                    ...
# 28679       911     Georgetown           Texas  Jeff "Howdy" Richards
# 28680       911     Georgetown           Texas  Jeff "Howdy" Richards
# 28681       911     Georgetown           Texas  Jeff "Howdy" Richards
# 28682       911     Georgetown           Texas  Jeff "Howdy" Richards
# 28683       911     Georgetown           Texas  Jeff "Howdy" Richards
#
#       Transaction Date  RewardsID   Prod Num  Sale Amount     Date
# ...

# %%
# monthy revenue for Texas and South Carolina over the full period covered by the data which is from 2022-01 to 2025-12
monthly_revenue = territory_sales.groupby(['State','Date'])[['Sale Amount']].sum().round(0).astype(int)

monthly_revenue
# Out:
#                         Sale Amount
# State          Date
# South Carolina 2022-01         9640
#                2022-02         9764
#                2022-03         8367
#                2022-04         8930
#                2022-05         5396
# ...                             ...
# Texas          2025-08        98631
#                2025-09       109066
#                2025-10       168956
#                2025-11       105401
#                2025-12        95571
#
# [96 rows x 1 columns]

# %% [markdown]
# ### Line chart for monthly revenue

# %%
# Separating Texas and South Carolina 
texas_rev = monthly_revenue.xs('Texas', level='State')
sc_rev = monthly_revenue.xs('South Carolina', level='State')

# Resetting the indexes to make them into columns
texas_rev = texas_rev.reset_index()
sc_rev = sc_rev.reset_index()

# %%
# Calling texas_rev
texas_rev
# Out:
#        Date  Sale Amount
# 0   2022-01        40857
# 1   2022-02        52729
# 2   2022-03        49215
# 3   2022-04        55229
# 4   2022-05        49697
# 5   2022-06        45208
# 6   2022-07        48309
# 7   2022-08        49641
# 8   2022-09        47977
# 9   2022-10        50543
# 10  2022-11        41402
# 11  2022-12        49056
# 12  2023-01        72299
# 13  2023-02        45399
# 14  2023-03        67469
# 15  2023-04        76712
# 16  2023-05        74059
# 17  2023-06        68340
# 18  2023-07        63941
# 19  2023-08        60701
# 20  2023-09        69674
# 21  2023-10        64725
# 22  2023-11        65553
# 23  2023-12        78994
# 24  2024-01        49824
# 25  2024-02        64549
# 26  2024-03        80724
# 27  2024-04        70048
# 28  2024-05        70733
# 29  2024-06        61548
# 30  2024-07        60701
# 31  2024-08        71514
# 32  2024-09        62885
# 33  2024-10        70342
# 34  2024-11        74205
# 35  2024-12        72299
# ...

# %%
# Calling sc_rev
sc_rev
# Out:
#        Date  Sale Amount     date
# 0   2022-01         9640  2022-01
# 1   2022-02         9764  2022-02
# 2   2022-03         8367  2022-03
# 3   2022-04         8930  2022-04
# 4   2022-05         5396  2022-05
# 5   2022-06         7196  2022-06
# 6   2022-07        13084  2022-07
# 7   2022-08         8916  2022-08
# 8   2022-09         8156  2022-09
# 9   2022-10        10330  2022-10
# 10  2022-11         8355  2022-11
# 11  2022-12         8361  2022-12
# 12  2023-01        13559  2023-01
# 13  2023-02        14068  2023-02
# 14  2023-03        13635  2023-03
# 15  2023-04         9588  2023-04
# 16  2023-05        10675  2023-05
# 17  2023-06         9332  2023-06
# 18  2023-07        10442  2023-07
# 19  2023-08        12617  2023-08
# 20  2023-09        10503  2023-09
# 21  2023-10        18688  2023-10
# 22  2023-11        10415  2023-11
# 23  2023-12        12742  2023-12
# 24  2024-01        15392  2024-01
# 25  2024-02        13575  2024-02
# ...

# %%
# Converting date column back to a string
texas_rev['Date'] = texas_rev['Date'].astype(str)
sc_rev['Date'] = sc_rev['Date'].astype(str)

# Creating a Line chart for monthly revenue
plt.figure(figsize=(12,8))
plt.plot(texas_rev['Date'],texas_rev['Sale Amount'], label='Texas', color='#BF5700')
plt.plot(sc_rev['Date'],sc_rev['Sale Amount'], label='South Carolina', color='#73000A')

plt.xticks(rotation=80, fontsize=10)
plt.xlabel('Date')
plt.ylabel('Revenue($)')

plt.title('Revenue Growth Gap Between Texas and South Carolina')
plt.legend()

plt.tight_layout()
plt.savefig('Revenue Gap Between Texas and South Carolina.jpg',bbox_inches='tight', pad_inches=.5)
plt.show()

# %% [markdown]
# ### How would you rank the sales performance of each store in each sales territory? Which are the top-performing stores?

# %%
# Creating a new df that is filtered down to just state storeID storeLocation by Total Revenue
total_rev = territory_sales.groupby(['State','Store ID','Store Location'])[['Sale Amount']].sum().round(0).astype(int)
total_rev.rename(columns={'Sale Amount':'Total Revenue'},inplace=True)


total_rev
# Out:
#                                         Total Revenue
# State          Store ID Store Location
# South Carolina 852      Charleston             311811
#                853      Greenville             337002
# Texas          901      Arlington              292987
#                902      Austin                 291145
#                903      Bacliff                280714
#                904      Baytown                298163
#                905      Beaumont               637819
#                906      Cedar Park             312628
#                907      Dallas                  54444
#                908      Denton                 298111
#                909      Desoto                 330720
#                910      Fort Worth             351773
#                911      Georgetown             269345

# %%
# Sorting total_rev in descending order to get the most revenue at the top and least revenue at the bottom
total_rev = total_rev.groupby('State',group_keys=False).apply(lambda x: x.sort_values('Total Revenue', ascending=False))
total_rev
# Out:
#                                         Total Revenue
# State          Store ID Store Location
# South Carolina 853      Greenville             337002
#                852      Charleston             311811
# Texas          905      Beaumont               637819
#                910      Fort Worth             351773
#                909      Desoto                 330720
#                906      Cedar Park             312628
#                904      Baytown                298163
#                908      Denton                 298111
#                901      Arlington              292987
#                902      Austin                 291145
#                903      Bacliff                280714
#                911      Georgetown             269345
#                907      Dallas                  54444

# %%
# creating a ranking system for each Territory
total_rev['Rank'] = total_rev.groupby('State',group_keys=False).apply(lambda x:x['Total Revenue'].rank(ascending=False).astype(int))
total_rev
# Out:
#                                         Total Revenue  Rank
# State          Store ID Store Location
# South Carolina 853      Greenville             337002     1
#                852      Charleston             311811     2
# Texas          905      Beaumont               637819     1
#                910      Fort Worth             351773     2
#                909      Desoto                 330720     3
#                906      Cedar Park             312628     4
#                904      Baytown                298163     5
#                908      Denton                 298111     6
#                901      Arlington              292987     7
#                902      Austin                 291145     8
#                903      Bacliff                280714     9
#                911      Georgetown             269345    10
#                907      Dallas                  54444    11

# %% [markdown]
# ### The top performing store for South Carolina is Greenville with $337,002
# ### The top performing store for Texas is Beaumont with $637,819

# %% [markdown]
# ### Creating a bar chart to show all stores performances

# %%
# Separating Texas and South Carolina 
texas_rank = total_rev.xs('Texas', level='State')
sc_rank = total_rev.xs('South Carolina', level='State')

# Resetting the indexes to make them into columns
texas_rank = texas_rank.reset_index()
sc_rank = sc_rank.reset_index()

# %%
# Calling texas_rank
texas_rank
# Out:
#     Store ID Store Location  Total Revenue  Rank
# 0        905       Beaumont         637819     1
# 1        910     Fort Worth         351773     2
# 2        909         Desoto         330720     3
# 3        906     Cedar Park         312628     4
# 4        904        Baytown         298163     5
# 5        908         Denton         298111     6
# 6        901      Arlington         292987     7
# 7        902         Austin         291145     8
# 8        903        Bacliff         280714     9
# 9        911     Georgetown         269345    10
# 10       907         Dallas          54444    11

# %%
# Calling sc_rank
sc_rank
# Out:
#    Store ID Store Location  Total Revenue  Rank
# 0       853     Greenville         337002     1
# 1       852     Charleston         311811     2

# %%
# Creating a horizontal bar chart

plt.figure(figsize=(12,8))

plt.barh(texas_rank['Store Location'],texas_rank['Total Revenue'], label='Texas', color='#BF5700')
plt.barh(sc_rank['Store Location'],sc_rank['Total Revenue'], label='South Carolina', color='#73000A')

plt.xlabel('Total Revenue($)')
plt.ylabel('Stores')

plt.title('Texas and South Carolina Total Revenue per 2022-2025')
plt.legend()

plt.tight_layout()
plt.savefig('Texas and South Carolina Total Revenue per 2022-2025.jpg',bbox_inches='tight', pad_inches=.5)
plt.show()

# %% [markdown]
# ###  Comparing the customer ID from the customer list data with the rewards ID from the sales data, who were the top customers in each sales territory?

# %%
# Merging territory_sales df with customer list to make a new df that
rewards_info = pd.merge(territory_sales,cx_list, left_on='RewardsID', right_on='cust_id')
rewards_info
# Out:
#       Store ID Store Location           State      Territory Manager  \
# 0          852     Charleston  South Carolina             Len Jensen
# 1          852     Charleston  South Carolina             Len Jensen
# 2          852     Charleston  South Carolina             Len Jensen
# 3          852     Charleston  South Carolina             Len Jensen
# 4          852     Charleston  South Carolina             Len Jensen
# ...        ...            ...             ...                    ...
# 2942       911     Georgetown           Texas  Jeff "Howdy" Richards
# 2943       911     Georgetown           Texas  Jeff "Howdy" Richards
# 2944       911     Georgetown           Texas  Jeff "Howdy" Richards
# 2945       911     Georgetown           Texas  Jeff "Howdy" Richards
# 2946       911     Georgetown           Texas  Jeff "Howdy" Richards
#
#      Transaction Date  RewardsID   Prod Num  Sale Amount     Date  cust_id  \
# ...

# %%
# Filtered rewards_info into a new df only having the columns that we need
rewards_mem = rewards_info[['State','cust_id','name','Sale Amount']]
rewards_mem
# Out:
#                State  cust_id             name  Sale Amount
# 0     South Carolina      466    Stringer Bell        52.90
# 1     South Carolina      230     Vince Masuka         4.00
# 2     South Carolina      177      Gina Waters       145.97
# 3     South Carolina      392  Dorothy Zbornak        20.36
# 4     South Carolina      292  Beverly Crusher        19.48
# ...              ...      ...              ...          ...
# 2942           Texas      111            Teddy       798.80
# 2943           Texas      102         Jodie L.         6.02
# 2944           Texas      130         Carly C.       152.40
# 2945           Texas       41    Michael Scott      1161.14
# 2946           Texas      311     Dawn Summers        23.44
#
# [2947 rows x 4 columns]

# %%
# Finding the total amount spent for each customer
total_cx_spent = rewards_mem.groupby(['State','cust_id','name'])[['Sale Amount']].sum().round(0).astype(int) # Filters down to just state,custid,name,and sale amount while also finidng the total sale amout per customer
total_cx_spent.rename(columns={'Sale Amount' : 'Total Spent'},inplace=True) # Just renames Sale Amount to Total Sales


total_cx_spent
# Out:
#                                              Total Spent
# State          cust_id name
# South Carolina 1       Rachel                         15
#                2       R. Geller                       6
#                3       Monica Geller                  58
#                5       Joey                           49
#                7       Gunther                       187
# ...                                                  ...
# Texas          517     Perry the Platypus             12
#                518     Baljeet                      1440
#                519     Buford                        368
#                520     Vanessa D.                    279
#                521     Linda Flynn-Fletcher           64
#
# [818 rows x 1 columns]

# %%
# Ordering the total spent by descending order and only showing top ten for each state
total_cust_spent = total_cx_spent.groupby('State',group_keys=False).apply(lambda x: x.sort_values('Total Spent', ascending=False)) # Orders customers from descending order based on how much they spent seperated by state 
top_10_cust = total_cust_spent.groupby('State', group_keys=False).apply(lambda x: x.head(10)) # only shows the top ten customers based on their total spent seperated by state

top_10_cust
# Out:
#                                                Total Spent
# State          cust_id name
# South Carolina 340     Jin Kwon                       1786
#                404     Roman Roy                      1779
#                213     Jazz                           1764
#                74      Ben Chang                      1567
#                280     Cal Abar                       1396
#                227     Debra Morgan                   1389
#                10      Emily                          1366
#                243     Dayanara Diaz                  1359
#                48      Andy B.                        1335
#                478     AJ Soprano                     1322
# Texas          344     Nate Jacobs                    5241
#                474     Christopher Moltisanti         3479
#                102     Jodie L.                       3465
#                168     Darius                         3400
# ...

# %% [markdown]
# ### What is the number of transactions per month by product category in each assigned territory?

# %%
# Merging Products and ProductCategories
prod_details = pd.merge(products,prod_cats, on=['CategoryID','SubcategoryID'])
prod_details
# Out:
#       Prod Num                               Product  CategoryID  \
# 0    105248-IT                      TCL NXTPAPER 10s         120
# 1    105249-IT         Dell Latitude 7320 Detachable         120
# 2    105250-IT                            Realme Pad         120
# 3    105251-IT                    Lenovo Tab P12 Pro         120
# 4    105252-IT               Microsoft Surface Pro 9         120
# ..         ...                                   ...         ...
# 679   105912-T               Networking Fundamentals         100
# 680   105913-T             Introduction to Databases         100
# 681  105914-IT    SanDisk Extreme Portable SSD (1TB)         120
# 682   105915-M  LTCA Year Up Spiral Notebook (Black)         130
# 683   105916-M       LTCA Year Up Sunglasses (Black)         130
#
#     SubcategoryID                  Category                Subcategory
# 0         120-tab  Technology & Accessories                    Tablets
# ...

# %%
# Merging prod_details and StoreSales
prod_sales = pd.merge(prod_details,territory_sales, on='Prod Num')
prod_sales
# Out:
#         Prod Num                               Product  CategoryID  \
# 0      105248-IT                      TCL NXTPAPER 10s         120
# 1      105248-IT                      TCL NXTPAPER 10s         120
# 2      105248-IT                      TCL NXTPAPER 10s         120
# 3      105248-IT                      TCL NXTPAPER 10s         120
# 4      105248-IT                      TCL NXTPAPER 10s         120
# ...          ...                                   ...         ...
# 29460   105915-M  LTCA Year Up Spiral Notebook (Black)         130
# 29461   105915-M  LTCA Year Up Spiral Notebook (Black)         130
# 29462   105915-M  LTCA Year Up Spiral Notebook (Black)         130
# 29463   105915-M  LTCA Year Up Spiral Notebook (Black)         130
# 29464   105916-M       LTCA Year Up Sunglasses (Black)         130
#
#       SubcategoryID                  Category                Subcategory  \
# 0           120-tab  Technology & Accessories                    Tablets
# ...

# %%
# cleaning up prod sales to get ready for monthly transaction per category
cat_monthly = prod_sales[['State','Date','Category','Sale Amount']]
cat_monthly
# Out:
#                 State     Date                  Category  Sale Amount
# 0      South Carolina  2022-04  Technology & Accessories       883.48
# 1      South Carolina  2023-12  Technology & Accessories       883.48
# 2      South Carolina  2024-11  Technology & Accessories       883.48
# 3      South Carolina  2025-01  Technology & Accessories       883.48
# 4      South Carolina  2025-04  Technology & Accessories       883.48
# ...               ...      ...                       ...          ...
# 29460  South Carolina  2022-09   Apparel and Merchandise        15.35
# 29461           Texas  2022-11   Apparel and Merchandise        15.35
# 29462           Texas  2022-09   Apparel and Merchandise        15.35
# 29463           Texas  2022-10   Apparel and Merchandise        15.35
# 29464           Texas  2022-10   Apparel and Merchandise        24.28
#
# [29465 rows x 4 columns]

# %%
# Counting the amount of transaction monthly
cat_monthly_transaction = cat_monthly.groupby(['State','Date','Category'])[['Sale Amount']].count()
cat_monthly_transaction.rename(columns={'Sale Amount' : 'Total Transaction'},inplace=True)

cat_monthly_transaction

# %% [markdown]
# ### Creating a subplot line charts for Texas and South Carolina

# %%
# Separting Texas and South Carolina
texas_transaction_monthly = cat_monthly_transaction.xs('Texas', level='State')
sc_transaction_montly = cat_monthly_transaction.xs('South Carolina', level='State')

# Resetting the indexes into columns
texas_transaction_monthly = texas_transaction_monthly.reset_index().pivot_table(index='Date', columns='Category',values='Total Transaction')
sc_transaction_montly = sc_transaction_montly.reset_index().pivot_table(index='Date',columns='Category',values='Total Transaction')

# %%
# Creating  subplot line chart for cat_monthly_transaction
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(12,6))

texas_transaction_monthly.plot(kind='line', ax=ax1)
ax1.set_title('Texas Monthly Transaction Count for 2022-2025')

ax1.get_legend().remove()
ax1.set_xlabel('Date')
ax1.set_ylabel('Transaction Count')

sc_transaction_montly.plot(kind='line', ax=ax2)
ax2.set_title('South Carolina Monthly Transaction Count for 2022-2025')

ax2.get_legend().remove()
ax2.set_xlabel('Date')
ax2.set_ylabel('Transaction Count')

handles, labels = ax1.get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center',ncol=6, bbox_to_anchor=(.5,-.5))

plt.tight_layout()
plt.savefig('Texas_and_SC_Monthly_Transaction_Count.jpg',bbox_inches='tight', pad_inches=.5)
plt.show()

# %% [markdown]
# ### What is total sales revenue per month by category?

# %%
# Total sales revenue per month by category
cat_monthly_revenue = cat_monthly.groupby(['State','Date','Category'])[['Sale Amount']].sum().round(0).astype(int)
cat_monthly_revenue
# Out:
#                                                  Sale Amount
# State          Date    Category
# South Carolina 2022-01 Apparel and Merchandise           257
#                        Art Supplies                      370
#                        Books (General)                    96
#                        Stationery and Supplies            61
#                        Technology & Accessories         7503
# ...                                                      ...
# Texas          2025-12 Art Supplies                     4027
#                        Books (General)                  2125
#                        Stationery and Supplies          1707
#                        Technology & Accessories        70286
#                        Textbooks                       12395
#
# [576 rows x 1 columns]

# %%
# Seperating texas and south carolina to two different df
texas_cat = cat_monthly_revenue.xs('Texas', level='State')
sc_cat = cat_monthly_revenue.xs('South Carolina', level='State')

# Resetting the indexes to make them into columns
texas_cat = texas_cat.reset_index().pivot_table(index='Date', columns='Category',values='Sale Amount')
sc_cat = sc_cat.reset_index().pivot_table(index='Date',columns='Category',values='Sale Amount')

# Filtering the charts to only include 2025
texas_2025 = texas_cat[texas_cat.index.year == 2025]
sc_2025 = sc_cat[sc_cat.index.year == 2025]

# %%
texas_cat.plot(kind='bar',stacked=True, figsize=(18,10))
plt.title('Texas Monthly Revenue by Product Category for 2022-2025')
plt.xticks(rotation=45)
plt.xlabel('Date')
plt.ylabel('Revenue ($)')

plt.tight_layout()
plt.savefig('Texas_Monthly_Revenue_2022-2025.jpg',bbox_inches='tight', pad_inches=.5)
plt.show()

# %%
sc_cat.plot(kind='bar',stacked=True, figsize=(18,10))
plt.title('South Carolina Monthly Revenue by Product Category for 2022-2025')
plt.xticks(rotation=45)
plt.xlabel('Date')
plt.ylabel('Revenue ($)')

plt.tight_layout()
plt.savefig('SouthCarolina_Monthly_Revenue_2022-2025.jpg',bbox_inches='tight', pad_inches=.5)
plt.show()

# %% [markdown]
# ### What might this tell you about the most popular products, and where could there be opportunity for growth?

# %% [markdown]
# This tells me that the most popular products are technology and stationery and supplies. Also that all categories got a boost in transaction counts in 2025. I think where there is opportunity for growth is in apparel as in both states it is generating the lowest revenue
# while it is in the middle of pack in terms of amount of transactions throughout the years. I believe that we can create bundles to pack apparel with other products or do more sales to bring in more revenue near the beginning of the school year.

# %% [markdown]
# ### What is your recommendation for where to focus marketing attention in the next quarter?

# %% [markdown]
# For my reccomendation based on my analysis of the Texas and South Carolina territories is that based on how the two stores in South Carolina are performing and keeping up with the stores in Texas, we should expand and open up more stores in South Carolina. While South Carolina is the 23rd most populous state which is still good, it is also recongized by the U.S Census Bureau as one of the fastest-growing states in the nation. With the two stores that we already have in SC(Charleston,Greenville), we have the most populous city and the 6th most populous city in the state who both have good universities.My suggestion would be to expand into the cities that have universities in SC. Which the following cities are #2 Columbia(University of South Carolina), #12 Spartanburg(USC Upstate,Wofford College),#15 Bluffton(USC Beaufort),#19 Conway(Coastal Carolina University),#34 Clemson(Clemson University),#48 Orangeburg(South Carolina State U). These numbers represent the rank by population and while some of these cities might have low population such as an average of 30k people, the majority of the population are college students and some of the colleges these cities have are big hitters such as Clemson University and Coastal Carolina University which are promiment schools not just in education but also sports and with that they also have really dedicated and passionate students and fans. With the expansion not only will South Carolina be closer to Texas in revenue but I also believe it is a territory that has a lot of potentional and could become one of our highest selling territories in the future.
